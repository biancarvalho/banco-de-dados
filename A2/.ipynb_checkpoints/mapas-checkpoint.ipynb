# %%
import sqlite3
import os
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
gjson = "geojs-100-mun.json"
br = gpd.read_file(gjson)
br = br.drop(columns = 'description')

# %%
br['name'] = br['name'].str.title()
br.head()
# Out:
#         id                   name  \
# 0  1100015  Alta Floresta D'Oeste
# 1  1100023              Ariquemes
# 2  1100031                 Cabixi
# 3  1100049                 Cacoal
# 4  1100056             Cerejeiras
#
#                                             geometry
# 0  POLYGON ((-62.18209 -11.86686, -62.16230 -11.8...
# 1  POLYGON ((-62.53595 -9.73182, -62.50782 -9.754...
# 2  POLYGON ((-60.39940 -13.45584, -60.40195 -13.4...
# 3  POLYGON ((-61.00051 -11.39796, -61.01794 -11.4...
# 4  POLYGON ((-61.50047 -13.00392, -61.47901 -13.0...

# %%
gjson1 = "pib.json"
pib = gpd.read_file(gjson1)
pib = pib.drop(columns = 'id')

# %%
pib = pib.sort_values('nome')
pib['nome'] = pib['nome'].str.title()
pib.head()
# Out:
#        gid            UF                 nome Censo         PIB  Pop_est_2009  \
# 4229   254       SERGIPE                Arauá  2010   63633.420       12042.0
# 3330  1076         GOIÁS      Abadia De Goiás  2010   38975.133        6301.0
# 3492  2687  MINAS GERAIS  Abadia Dos Dourados  2010   71222.170        6805.0
# 3976  1077         GOIÁS            Abadiânia  2010   82400.490       13378.0
# 2115  2138          PARÁ           Abaetetuba  2010  456256.940      139819.0
#
#       PIB_percapita                         Descrição             legenda  \
# 4229        5284.29  Produto Interno Bruto per capita           - 9639.65
# 3330        6185.55  Produto Interno Bruto per capita           - 9639.65
# 3492       10466.15  Produto Interno Bruto per capita  9639.65 - 22144.80
# 3976        6159.40  Produto Interno Bruto per capita           - 9639.65
# 2115        3263.20  Produto Interno Bruto per capita           - 9639.65
#
# ...

# %%
pib['PIB_percapita'] = pib['PIB_percapita'].astype(float)
pib['Pop_est_2009'] = pib['Pop_est_2009'].astype(float)

# %%
f = plt.figure(figsize=(12,5))

ax=f.add_subplot(121)
pib.plot(column='PIB_percapita', cmap='hot', edgecolor='None', figsize=(15,8), ax=ax)

ax=f.add_subplot(122)
pib.plot(column='Pop_est_2009', cmap='hot', edgecolor='None', figsize=(15,8), ax=ax)
# Out:
# <AxesSubplot:>

# %%
am = pib[pib['UF'] == 'AMAZONAS']

# %%
f = plt.figure(figsize=(12,5))

ax=f.add_subplot(121)
am.plot(column='PIB_percapita', cmap='hot', edgecolor='None', figsize=(15,8), ax=ax)

ax=f.add_subplot(122)
am.plot(column='Pop_est_2009', cmap='hot', edgecolor='None', figsize=(15,8), ax=ax)
# Out:
# <AxesSubplot:>

# %%
se = pib[pib['UF'] == 'SERGIPE']

# %%
f = plt.figure(figsize=(12,5))

ax=f.add_subplot(121)
se.plot(column='PIB_percapita', cmap='hot', edgecolor='None', figsize=(15,8), ax=ax)

ax=f.add_subplot(122)
se.plot(column='Pop_est_2009', cmap='hot', edgecolor='None', figsize=(15,8), ax=ax)
# Out:
# <AxesSubplot:>

# %%
es = pib[pib['UF'] == 'ESPIRITO SANTO']

# %%
f = plt.figure(figsize=(12,5))

ax=f.add_subplot(121)
es.plot(column='PIB_percapita', cmap='hot', edgecolor='None', figsize=(15,8), ax=ax)
plt.legend()
plt.xlim(-42.25,-39.25)

ax=f.add_subplot(122)
es.plot(column='Pop_est_2009', cmap='hot', edgecolor='None', figsize=(15,8), ax=ax)
plt.xlim(-42.25,-39.25)
# Out:
# No handles with labels found to put in legend.
# (-42.25, -39.25)

# %%
sp = pib[pib['UF'] == 'SÃO PAULO']

# %%
f = plt.figure(figsize=(12,5))

ax=f.add_subplot(121)
sp.plot(column='PIB_percapita', cmap='hot', edgecolor='None', figsize=(15,8), ax=ax)

ax=f.add_subplot(122)
sp.plot(column='Pop_est_2009', cmap='hot', edgecolor='None', figsize=(15,8), ax=ax)
# Out:
# <AxesSubplot:>

# %%
br_a1 = pib[pib['PIB_percapita'] < 10977.027145] #PIB per capita abaixo da média
br_a2 = pib[pib['PIB_percapita'] >= 10977.027145] #PIB per capita acima da média
br_a3 = pib[pib['Pop_est_2009'] < 34405.572763] #População abaixo da média
br_a4 = pib[pib['Pop_est_2009'] >= 34405.572763] #População acima da média

# %%
f = plt.figure(figsize=(12,10))

ax=f.add_subplot(221)
br_a1.plot(column='PIB_percapita', cmap='hot', edgecolor='None', figsize=(15,8), ax=ax)

ax=f.add_subplot(222)
br_a2.plot(column='PIB_percapita', cmap='hot', edgecolor='None', figsize=(15,8), ax=ax)

ax=f.add_subplot(223)
br_a3.plot(column='Pop_est_2009', cmap='hot', edgecolor='None', figsize=(15,8), ax=ax)

ax=f.add_subplot(224)
br_a4.plot(column='Pop_est_2009', cmap='hot', edgecolor='None', figsize=(15,8), ax=ax)
# Out:
# <AxesSubplot:>
