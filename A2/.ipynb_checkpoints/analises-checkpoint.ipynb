# %%
import geopandas as gpd
import pandas as pd
import sqlite3
import os

# %% [markdown]
# # Importando os bancos de dados

# %%
conn = sqlite3.connect(os.path.join('pib.db'))
query= "SELECT * FROM pib"
pib_df = pd.read_sql(query,conn)
conn.close()
pib=pib_df.copy()
pib_df.head(1)
# Out:
#    index                                               id  gid     UF  \
# 0      0  vw_pib_percapita.fid-2e5b397f_17cf1b12db8_-5754  215  BAHIA
#
#        nome Censo        PIB  Pop_est_2009  PIB_percapita     legenda  classe  \
# 0  Tremedal  2010  57883.992       18433.0        3140.24   - 9639.65       1
#
#                                             geometry
# 0  MULTIPOLYGON (((-41.45880331 -14.78141546, -41...

# %%
conn = sqlite3.connect(os.path.join('racial.db'))
query= "SELECT * FROM racial"
racial_df = pd.read_sql(query,conn)
conn.close()
racial=racial_df.copy()
racial_df.head(1)
# Out:
#    index                                                 id  gid     UF  \
# 0      0  vw_per_pessoas_pretas.fid-60efe8e1_17d582643c1...  215  BAHIA
#
#        nome Censo  POP_TOT  Pessoas_Pretas  PER_Pessoas_Pretas  \
# 0  Tremedal  2010  17029.0             827            4.856421
#
#                                            descricao        legenda  classe  \
# 0  Percentual de pessoas residentes de cor ou raç...  4,22% - 7,79%       2
#
#                                             geometry
# 0  MULTIPOLYGON (((-41.45880331 -14.78141546, -41...

# %% [markdown]
# ### Transformando os DataFrames para o tipo GeoDataFrame

# %%
pib['geometry']=gpd.GeoSeries.from_wkt(pib_df['geometry'])
pib = gpd.GeoDataFrame(pib, geometry='geometry')
pib.head(1)
# Out:
#    index                                               id  gid     UF  \
# 0      0  vw_pib_percapita.fid-2e5b397f_17cf1b12db8_-5754  215  BAHIA
#
#        nome Censo        PIB  Pop_est_2009  PIB_percapita     legenda  classe  \
# 0  Tremedal  2010  57883.992       18433.0        3140.24   - 9639.65       1
#
#                                             geometry
# 0  MULTIPOLYGON (((-41.45880 -14.78142, -41.45497...

# %%
racial['geometry']=gpd.GeoSeries.from_wkt(racial['geometry'])
racial = gpd.GeoDataFrame(racial, geometry='geometry')
racial.head(1)
# Out:
#    index                                                 id  gid     UF  \
# 0      0  vw_per_pessoas_pretas.fid-60efe8e1_17d582643c1...  215  BAHIA
#
#        nome Censo  POP_TOT  Pessoas_Pretas  PER_Pessoas_Pretas  \
# 0  Tremedal  2010  17029.0             827            4.856421
#
#                                            descricao        legenda  classe  \
# 0  Percentual de pessoas residentes de cor ou raç...  4,22% - 7,79%       2
#
#                                             geometry
# 0  MULTIPOLYGON (((-41.45880 -14.78142, -41.45497...

# %% [markdown]
# ## Tratando os dados

# %%
pib = pib.sort_values('nome')
pib['nome'] = pib['nome'].str.title()
pib.head(2)
# Out:
#       index                                               id   gid       UF  \
# 4229   4229  vw_pib_percapita.fid-2e5b397f_17cf1b12db8_-2f6f   254  SERGIPE
# 3330   3330  vw_pib_percapita.fid-2e5b397f_17cf1b12db8_-32f2  1076    GOIÁS
#
#                  nome Censo        PIB  Pop_est_2009  PIB_percapita  \
# 4229            Arauá  2010  63633.420       12042.0        5284.29
# 3330  Abadia De Goiás  2010  38975.133        6301.0        6185.55
#
#          legenda  classe                                           geometry
# 4229   - 9639.65       1  MULTIPOLYGON (((-37.50771 -11.27151, -37.50658...
# 3330   - 9639.65       1  MULTIPOLYGON (((-49.44332 -16.72349, -49.44079...

# %%
racial = racial.sort_values('nome')
racial['nome'] = racial['nome'].str.title()
racial.head(2)
# Out:
#       index                                                 id   gid       UF  \
# 4229   4229  vw_per_pessoas_pretas.fid-60efe8e1_17d582910ee...   254  SERGIPE
# 3330   3330  vw_per_pessoas_pretas.fid-60efe8e1_17d582643c1...  1076    GOIÁS
#
#                  nome Censo  POP_TOT  Pessoas_Pretas  PER_Pessoas_Pretas  \
# 4229            Arauá  2010  10878.0            1525           14.019121
# 3330  Abadia De Goiás  2010   6876.0             405            5.890052
#
#                                               descricao          legenda  \
# 4229  Percentual de pessoas residentes de cor ou raç...  12,80% - 21,76%
# 3330  Percentual de pessoas residentes de cor ou raç...    4,22% - 7,79%
#
#       classe                                           geometry
# 4229       4  MULTIPOLYGON (((-37.50771 -11.27151, -37.50658...
# 3330       2  MULTIPOLYGON (((-49.44332 -16.72349, -49.44079...

# %% [markdown]
# ### Unindo os Dataframes sobre o PIB e a população negra

# %%
racial_dfn = racial_df.drop(racial_df.columns[[0,1,3,4,5,9,12]], axis=1) #retirando colunas iguais
merge = pd.merge(pib_df, racial_dfn, how='outer', on='gid')

# %% [markdown]
# Transformando em GeoDataFrame

# %%
merge['geometry']=gpd.GeoSeries.from_wkt(merge['geometry'])
merge = gpd.GeoDataFrame(merge, geometry='geometry')
merge.head(1)
# Out:
#    index                                               id  gid     UF  \
# 0      0  vw_pib_percapita.fid-2e5b397f_17cf1b12db8_-5754  215  BAHIA
#
#        nome Censo        PIB  Pop_est_2009  PIB_percapita   legenda_x  \
# 0  Tremedal  2010  57883.992       18433.0        3140.24   - 9639.65
#
#    classe_x                                           geometry  POP_TOT  \
# 0         1  MULTIPOLYGON (((-41.45880 -14.78142, -41.45497...  17029.0
#
#    Pessoas_Pretas  PER_Pessoas_Pretas      legenda_y  classe_y
# 0             827            4.856421  4,22% - 7,79%         2

# %% [markdown]
# ## Analisando os dados

# %%
merge['PIB_percapita'] = merge['PIB_percapita'].astype(float)
merge['Pop_est_2009'] = merge['Pop_est_2009'].astype(float)
merge['PER_Pessoas_Pretas'] = merge['PER_Pessoas_Pretas'].astype(float)

# %%
merge[['PIB', 'Pop_est_2009', 'PIB_percapita', 'PER_Pessoas_Pretas']].agg(['mean', 'median'])
# Out:
#                   PIB  Pop_est_2009  PIB_percapita  PER_Pessoas_Pretas
# mean    582020.311889  34405.572763   10977.027145            6.410117
# median   80591.720000  11203.000000    8393.170000            5.175179

# %% [markdown]
# ## Plotando os dados

# %%
merge.plot(color='green', edgecolor='None', figsize=(15,8))
# Out:
# <AxesSubplot:>
